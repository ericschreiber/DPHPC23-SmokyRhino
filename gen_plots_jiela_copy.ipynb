# %%
import pandas as pd
import os
import seaborn as sns

# kill old plots
for f in os.listdir('plots/correctness_test_jiela/scaling'):
    os.remove(os.path.join('plots/correctness_test_jiela/scaling', f))
for f in os.listdir('plots/correctness_test_jiela/all_impls'):
    os.remove(os.path.join('plots/correctness_test_jiela/all_impls', f))

# %% [markdown]
# ### Global params

# %%
num_warmups = 20  # with the full data this should probably be something like 20
consistency_check = False
implementations_to_ignore = [
    # 'coo_opt_vectorization_SDDMM_GPU',
    # 'merged',
    # 'naive_SDDMM_GPU',
    # 'naive_coo_SDDMM_GPU',
    # 'semi_naive_CSR_SDDMM_GPU'
    ]
log_scale = False

# %% [markdown]
# ### Load data

# %%
# This list only contains the relevant paths!
base_paths = [
    # "/scratch/eschreib/results_full_run/",
    # "/scratch/eschreib/results_downloaded_size_generated/",
    # "/scratch/eschreib/results_downloaded_24k_generated/"
    # "/scratch/eschreib/results_MatrixMarket_10k/",
    # "/scratch/eschreib/results_MatrixMarket_24k/"
    "/scratch/eschreib/results_ABsquare/"
    ]

# All the irrelevant paths we have, if you want to test a specific one, put it into the base_paths list
    # "/scratch/eschreib/results/"
    # "/scratch/eschreib/results_K100/"
    # "/scratch/eschreib/results_MatrixMarket/"
    # "/scratch/eschreib/results_test/"

# The paths that are actually relevant
# "/scratch/eschreib/results_full_run/"
# "/scratch/eschreib/results_downloaded_size_generated/"
# "/scratch/eschreib/results_downloaded_24k_generated/"
# "/scratch/eschreib/results_MatrixMarket_10k/"
# "/scratch/eschreib/results_MatrixMarket_24k/"

# create the dataframe to which we can append our sub-dataframes
data = pd.DataFrame()

for base_path in base_paths:

    # collect all files that contain run data
    file_paths = []
    impl_name = os.listdir(base_path)
    for impl in impl_name:
        sizes = os.listdir(base_path + impl)
        # there is exactly one csv file per size_dir
        for size_dir in sizes:
            files = os.listdir(base_path + impl + "/" + size_dir)
            file_path = base_path + impl + "/" + size_dir + "/" + files[0]  # only one csv file per dir
            file_paths.append(file_path)
    sub_data = []
    for file in file_paths:
        with open(file, 'r') as fin:
            size = file.split("/")[-2]
            lines = fin.readlines()
            lines.pop(0)  # remove header line
            lines = list(map(lambda x: x.replace(",\n", ""), lines))  # remove trailing newline since they would create an extra column at the end
            lines = list(map(lambda x: x.split(","), lines))  # split into columns
            lines = list(map(lambda x: [x[0]] + ["0." + (x[3].split("/")[-1].split(".")[0].split("_")[-1][1:])] + x[1:], lines))
            lines = list(map(lambda x: [x[0]] + [size] + x[1:], lines))  # add size info
            sub_data += lines
    # make a subdata dataframe and add an indicator if we want it to be in the special configurations plot
    special_config = base_path != "/scratch/eschreib/results_full_run/"
        
    sub_data = pd.DataFrame(sub_data)
    sub_data["special_config"] = special_config
    # add the subdata to our main big dataframe
    data = pd.concat([data, sub_data], axis=0)

data
# Out:
#                                   0            1        2  \
# 0          semi_naive_CSR_SDDMM_GPU    1000x1000    0.005
# 1          semi_naive_CSR_SDDMM_GPU    1000x1000    0.001
# 2          semi_naive_CSR_SDDMM_GPU    1000x1000   0.0005
# 3          semi_naive_CSR_SDDMM_GPU    1000x1000   0.0001
# 4          semi_naive_CSR_SDDMM_GPU    1000x1000  0.00001
# 5          semi_naive_CSR_SDDMM_GPU  10000x10000    0.005
# 6          semi_naive_CSR_SDDMM_GPU  10000x10000    0.001
# 7          semi_naive_CSR_SDDMM_GPU  10000x10000   0.0005
# 8          semi_naive_CSR_SDDMM_GPU  10000x10000   0.0001
# 9          semi_naive_CSR_SDDMM_GPU  10000x10000  0.00001
# 10  coo_opt_vectorization_SDDMM_GPU    1000x1000    0.005
# 11  coo_opt_vectorization_SDDMM_GPU    1000x1000    0.001
# 12  coo_opt_vectorization_SDDMM_GPU    1000x1000   0.0005
# 13  coo_opt_vectorization_SDDMM_GPU    1000x1000   0.0001
# 14  coo_opt_vectorization_SDDMM_GPU    1000x1000  0.00001
# 15  coo_opt_vectorization_SDDMM_GPU  10000x10000    0.005
# 16  coo_opt_vectorization_SDDMM_GPU  10000x10000    0.001
# 17  coo_opt_vectorization_SDDMM_GPU  10000x10000   0.0005
# 18  coo_opt_vectorization_SDDMM_GPU  10000x10000   0.0001
# 19  coo_opt_vectorization_SDDMM_GPU  10000x10000  0.00001
# 20              naive_coo_SDDMM_GPU    1000x1000    0.005
# 21              naive_coo_SDDMM_GPU    1000x1000    0.001
# 22              naive_coo_SDDMM_GPU    1000x1000   0.0005
# 23              naive_coo_SDDMM_GPU    1000x1000   0.0001
# 24              naive_coo_SDDMM_GPU    1000x1000  0.00001
# 25              naive_coo_SDDMM_GPU  10000x10000    0.005
# 26              naive_coo_SDDMM_GPU  10000x10000    0.001
# 27              naive_coo_SDDMM_GPU  10000x10000   0.0005
# 28              naive_coo_SDDMM_GPU  10000x10000   0.0001
# 29              naive_coo_SDDMM_GPU  10000x10000  0.00001
# 30                  naive_SDDMM_GPU    1000x1000    0.005
# 31                  naive_SDDMM_GPU    1000x1000    0.001
# 32                  naive_SDDMM_GPU    1000x1000   0.0005
# 33                  naive_SDDMM_GPU    1000x1000   0.0001
# 34                  naive_SDDMM_GPU    1000x1000  0.00001
# 35                  naive_SDDMM_GPU  10000x10000    0.005
# 36                  naive_SDDMM_GPU  10000x10000    0.001
# 37                  naive_SDDMM_GPU  10000x10000   0.0005
# 38                  naive_SDDMM_GPU  10000x10000   0.0001
# 39                  naive_SDDMM_GPU  10000x10000  0.00001
# 40                           merged    1000x1000    0.005
# 41                           merged    1000x1000    0.001
# 42                           merged    1000x1000   0.0005
# 43                           merged    1000x1000   0.0001
# 44                           merged    1000x1000  0.00001
# 45                           merged  10000x10000    0.005
# 46                           merged  10000x10000    0.001
# 47                           merged  10000x10000   0.0005
# 48                           merged  10000x10000   0.0001
# 49                           merged  10000x10000  0.00001
#
#                                                     3  \
# 0   /scratch/eschreib/matrices/Dataset_generated_m...
# 1   /scratch/eschreib/matrices/Dataset_generated_m...
# 2   /scratch/eschreib/matrices/Dataset_generated_m...
# 3   /scratch/eschreib/matrices/Dataset_generated_m...
# 4   /scratch/eschreib/matrices/Dataset_generated_m...
# 5   /scratch/eschreib/matrices/Dataset_generated_m...
# 6   /scratch/eschreib/matrices/Dataset_generated_m...
# 7   /scratch/eschreib/matrices/Dataset_generated_m...
# 8   /scratch/eschreib/matrices/Dataset_generated_m...
# 9   /scratch/eschreib/matrices/Dataset_generated_m...
# 10  /scratch/eschreib/matrices/Dataset_generated_m...
# 11  /scratch/eschreib/matrices/Dataset_generated_m...
# 12  /scratch/eschreib/matrices/Dataset_generated_m...
# 13  /scratch/eschreib/matrices/Dataset_generated_m...
# 14  /scratch/eschreib/matrices/Dataset_generated_m...
# 15  /scratch/eschreib/matrices/Dataset_generated_m...
# 16  /scratch/eschreib/matrices/Dataset_generated_m...
# 17  /scratch/eschreib/matrices/Dataset_generated_m...
# 18  /scratch/eschreib/matrices/Dataset_generated_m...
# 19  /scratch/eschreib/matrices/Dataset_generated_m...
# 20  /scratch/eschreib/matrices/Dataset_generated_m...
# 21  /scratch/eschreib/matrices/Dataset_generated_m...
# 22  /scratch/eschreib/matrices/Dataset_generated_m...
# 23  /scratch/eschreib/matrices/Dataset_generated_m...
# 24  /scratch/eschreib/matrices/Dataset_generated_m...
# 25  /scratch/eschreib/matrices/Dataset_generated_m...
# 26  /scratch/eschreib/matrices/Dataset_generated_m...
# 27  /scratch/eschreib/matrices/Dataset_generated_m...
# 28  /scratch/eschreib/matrices/Dataset_generated_m...
# 29  /scratch/eschreib/matrices/Dataset_generated_m...
# 30  /scratch/eschreib/matrices/Dataset_generated_m...
# 31  /scratch/eschreib/matrices/Dataset_generated_m...
# 32  /scratch/eschreib/matrices/Dataset_generated_m...
# 33  /scratch/eschreib/matrices/Dataset_generated_m...
# 34  /scratch/eschreib/matrices/Dataset_generated_m...
# 35  /scratch/eschreib/matrices/Dataset_generated_m...
# 36  /scratch/eschreib/matrices/Dataset_generated_m...
# 37  /scratch/eschreib/matrices/Dataset_generated_m...
# 38  /scratch/eschreib/matrices/Dataset_generated_m...
# 39  /scratch/eschreib/matrices/Dataset_generated_m...
# 40  /scratch/eschreib/matrices/Dataset_generated_m...
# 41  /scratch/eschreib/matrices/Dataset_generated_m...
# 42  /scratch/eschreib/matrices/Dataset_generated_m...
# 43  /scratch/eschreib/matrices/Dataset_generated_m...
# 44  /scratch/eschreib/matrices/Dataset_generated_m...
# 45  /scratch/eschreib/matrices/Dataset_generated_m...
# 46  /scratch/eschreib/matrices/Dataset_generated_m...
# 47  /scratch/eschreib/matrices/Dataset_generated_m...
# 48  /scratch/eschreib/matrices/Dataset_generated_m...
# 49  /scratch/eschreib/matrices/Dataset_generated_m...
#
#                                                     4  \
# 0   /scratch/eschreib/matrices/Dataset_generated_m...
# 1   /scratch/eschreib/matrices/Dataset_generated_m...
# 2   /scratch/eschreib/matrices/Dataset_generated_m...
# 3   /scratch/eschreib/matrices/Dataset_generated_m...
# 4   /scratch/eschreib/matrices/Dataset_generated_m...
# 5   /scratch/eschreib/matrices/Dataset_generated_m...
# 6   /scratch/eschreib/matrices/Dataset_generated_m...
# 7   /scratch/eschreib/matrices/Dataset_generated_m...
# 8   /scratch/eschreib/matrices/Dataset_generated_m...
# 9   /scratch/eschreib/matrices/Dataset_generated_m...
# 10  /scratch/eschreib/matrices/Dataset_generated_m...
# 11  /scratch/eschreib/matrices/Dataset_generated_m...
# 12  /scratch/eschreib/matrices/Dataset_generated_m...
# 13  /scratch/eschreib/matrices/Dataset_generated_m...
# 14  /scratch/eschreib/matrices/Dataset_generated_m...
# 15  /scratch/eschreib/matrices/Dataset_generated_m...
# 16  /scratch/eschreib/matrices/Dataset_generated_m...
# 17  /scratch/eschreib/matrices/Dataset_generated_m...
# 18  /scratch/eschreib/matrices/Dataset_generated_m...
# 19  /scratch/eschreib/matrices/Dataset_generated_m...
# 20  /scratch/eschreib/matrices/Dataset_generated_m...
# 21  /scratch/eschreib/matrices/Dataset_generated_m...
# 22  /scratch/eschreib/matrices/Dataset_generated_m...
# 23  /scratch/eschreib/matrices/Dataset_generated_m...
# 24  /scratch/eschreib/matrices/Dataset_generated_m...
# 25  /scratch/eschreib/matrices/Dataset_generated_m...
# 26  /scratch/eschreib/matrices/Dataset_generated_m...
# 27  /scratch/eschreib/matrices/Dataset_generated_m...
# 28  /scratch/eschreib/matrices/Dataset_generated_m...
# 29  /scratch/eschreib/matrices/Dataset_generated_m...
# 30  /scratch/eschreib/matrices/Dataset_generated_m...
# 31  /scratch/eschreib/matrices/Dataset_generated_m...
# 32  /scratch/eschreib/matrices/Dataset_generated_m...
# 33  /scratch/eschreib/matrices/Dataset_generated_m...
# 34  /scratch/eschreib/matrices/Dataset_generated_m...
# 35  /scratch/eschreib/matrices/Dataset_generated_m...
# 36  /scratch/eschreib/matrices/Dataset_generated_m...
# 37  /scratch/eschreib/matrices/Dataset_generated_m...
# 38  /scratch/eschreib/matrices/Dataset_generated_m...
# 39  /scratch/eschreib/matrices/Dataset_generated_m...
# 40  /scratch/eschreib/matrices/Dataset_generated_m...
# 41  /scratch/eschreib/matrices/Dataset_generated_m...
# 42  /scratch/eschreib/matrices/Dataset_generated_m...
# 43  /scratch/eschreib/matrices/Dataset_generated_m...
# 44  /scratch/eschreib/matrices/Dataset_generated_m...
# 45  /scratch/eschreib/matrices/Dataset_generated_m...
# 46  /scratch/eschreib/matrices/Dataset_generated_m...
# 47  /scratch/eschreib/matrices/Dataset_generated_m...
# 48  /scratch/eschreib/matrices/Dataset_generated_m...
# 49  /scratch/eschreib/matrices/Dataset_generated_m...
#
#                                                     5                 6  \
# 0   /scratch/eschreib/matrices/Dataset_generated_m...      69632.001221
# 1   /scratch/eschreib/matrices/Dataset_generated_m...      35840.000957
# 2   /scratch/eschreib/matrices/Dataset_generated_m...      30719.999224
# 3   /scratch/eschreib/matrices/Dataset_generated_m...      24576.000869
# 4   /scratch/eschreib/matrices/Dataset_generated_m...      22528.000176
# 5   /scratch/eschreib/matrices/Dataset_generated_m...   44125183.105469
# 6   /scratch/eschreib/matrices/Dataset_generated_m...    8886272.430420
# 7   /scratch/eschreib/matrices/Dataset_generated_m...    4487167.835236
# 8   /scratch/eschreib/matrices/Dataset_generated_m...     979968.011379
# 9   /scratch/eschreib/matrices/Dataset_generated_m...     149504.005909
# 10  /scratch/eschreib/matrices/Dataset_generated_m...     226093.000000
# 11  /scratch/eschreib/matrices/Dataset_generated_m...     282544.000000
# 12  /scratch/eschreib/matrices/Dataset_generated_m...     182583.000000
# 13  /scratch/eschreib/matrices/Dataset_generated_m...      65611.000000
# 14  /scratch/eschreib/matrices/Dataset_generated_m...      48311.000000
# 15  /scratch/eschreib/matrices/Dataset_generated_m...   99284143.000000
# 16  /scratch/eschreib/matrices/Dataset_generated_m...   30716101.000000
# 17  /scratch/eschreib/matrices/Dataset_generated_m...   12922328.000000
# 18  /scratch/eschreib/matrices/Dataset_generated_m...    4177011.000000
# 19  /scratch/eschreib/matrices/Dataset_generated_m...    4305443.000000
# 20  /scratch/eschreib/matrices/Dataset_generated_m...     653312.027454
# 21  /scratch/eschreib/matrices/Dataset_generated_m...     872448.027134
# 22  /scratch/eschreib/matrices/Dataset_generated_m...     518144.011497
# 23  /scratch/eschreib/matrices/Dataset_generated_m...     129023.998976
# 24  /scratch/eschreib/matrices/Dataset_generated_m...      65535.999835
# 25  /scratch/eschreib/matrices/Dataset_generated_m...  248230880.737305
# 26  /scratch/eschreib/matrices/Dataset_generated_m...   76130561.828613
# 27  /scratch/eschreib/matrices/Dataset_generated_m...   38747295.379639
# 28  /scratch/eschreib/matrices/Dataset_generated_m...   15742976.188660
# 29  /scratch/eschreib/matrices/Dataset_generated_m...   16195583.343506
# 30  /scratch/eschreib/matrices/Dataset_generated_m...     295744.001865
# 31  /scratch/eschreib/matrices/Dataset_generated_m...     280831.992626
# 32  /scratch/eschreib/matrices/Dataset_generated_m...     284256.011248
# 33  /scratch/eschreib/matrices/Dataset_generated_m...     282624.006271
# 34  /scratch/eschreib/matrices/Dataset_generated_m...     282431.989908
# 35  /scratch/eschreib/matrices/Dataset_generated_m...  153703353.881836
# 36  /scratch/eschreib/matrices/Dataset_generated_m...  152423904.418945
# 37  /scratch/eschreib/matrices/Dataset_generated_m...  154035873.413086
# 38  /scratch/eschreib/matrices/Dataset_generated_m...  155164443.969727
# 39  /scratch/eschreib/matrices/Dataset_generated_m...  152681945.800781
# 40  /scratch/eschreib/matrices/Dataset_generated_m...     125952.005386
# 41  /scratch/eschreib/matrices/Dataset_generated_m...      58368.001133
# 42  /scratch/eschreib/matrices/Dataset_generated_m...      45056.000352
# 43  /scratch/eschreib/matrices/Dataset_generated_m...      32767.999917
# 44  /scratch/eschreib/matrices/Dataset_generated_m...      30719.999224
# 45  /scratch/eschreib/matrices/Dataset_generated_m...   26644479.751587
# 46  /scratch/eschreib/matrices/Dataset_generated_m...    5762047.767639
# 0              None           True
# 1              None           True
# 2              None           True
# 3              None           True
# 4              None           True
# 5              None           True
# 6              None           True
# 7              None           True
# 8              None           True
# 9              None           True
# 10             None           True
# 11             None           True
# 12             None           True
# 13             None           True
# 14             None           True
# 15             None           True
# 16             None           True
# 17             None           True
# 18             None           True
# 19             None           True
# 20             None           True
# 21             None           True
# 22             None           True
# 23             None           True
# 24             None           True
# 25             None           True
# 26             None           True
# 27             None           True
# 28             None           True
# 29             None           True
# 30             None           True
# 31             None           True
# 32             None           True
# 33             None           True
# 34             None           True
# 35             None           True
# 36             None           True
# 37             None           True
# 38             None           True
# 39             None           True
# 40    121855.996549           True
# 41     43007.999659           True
# 42     30719.999224           True
# 43     20479.999483           True
# 44     18432.000652           True
# 45  26634239.196777           True
# 46   5761023.998260           True
# 47   3137536.048889           True
# 48    870400.011539           True
# 49    206847.995520           True
#
# [50 rows x 227 columns]

# %% [markdown]
# ### Preprocess data

# %%
# A helper function to turn the sparsities int percentages
def to_percent (a):
    # remove 3 characters
    a = a[3:]
    # We assume that we never have more than 9._%
    before_comma = a[0]
    a = a[1:]
    a = before_comma + "." + a + "%"

    return a

# remove warmup measurements
metadata = data.iloc[:, :3]
measurements = data.iloc[:, 3:]
measurements = measurements.iloc[:, num_warmups:]
data = pd.concat([metadata, measurements], axis=1)
print(data)
# remove all the broken runs (= the impls that start with "**")
data = data[~data[0].str.startswith("**")]

# prettify df
data = data.drop(data.columns[[3, 4, 5]], axis=1)  # rm the paths to the matrices
data = data.sort_values(by=[0])  # sort by implementation name
data.columns = range(data.shape[1])  # reset the column names to consecutive numbers
data.head()

sparsities = data[2].unique()
print(sparsities)
data[2] = data[2].apply(to_percent)

impls = data[0].unique()
sizes = data[1].unique()
sparsities = data[2].unique()
sparsities.sort()  # if I don't seaborn messes up the order of the x axis in some plots

print(impls)
print(sizes)
print(sparsities)

# data
# print(data)

# We now expand such that we can use seaborn
# specifically this means we only have one measurement per row
# d_exp stands for data expanded. Meaning each row only contains a single measurement
 
d_exp = pd.DataFrame(columns=['implementation', 'size', 'sparsity', 'ns', 'configuration'])

for row_idx in range(len(data)):

    row = data.iloc[row_idx]
    row_len = len(row)

    cur_imp = row[0]
    cur_size = row[1]
    cur_spars = row[2]
    cur_conf = row[row_len-1]
    current_configuration = "No"

    if cur_conf:
        current_configuration = "size: " + cur_size + " sparsity: " + cur_spars

    for measurement in row[3:]:

        if measurement is not None:
            new_row = {'implementation': cur_imp, 'size': cur_size, 'sparsity': cur_spars, 'ns': float(measurement), 'configuration':current_configuration}
            d_exp.loc[len(d_exp)] = new_row

configurations = d_exp["configuration"].unique()
configurations.sort()

d_exp
# Out:
#                                   0            1        2                23  \
# 0          semi_naive_CSR_SDDMM_GPU    1000x1000    0.005      53247.999400
# 1          semi_naive_CSR_SDDMM_GPU    1000x1000    0.001      20479.999483
# 2          semi_naive_CSR_SDDMM_GPU    1000x1000   0.0005      15359.999612
# 3          semi_naive_CSR_SDDMM_GPU    1000x1000   0.0001      11264.000088
# 4          semi_naive_CSR_SDDMM_GPU    1000x1000  0.00001      10239.999741
# 5          semi_naive_CSR_SDDMM_GPU  10000x10000    0.005   44192768.096924
# 6          semi_naive_CSR_SDDMM_GPU  10000x10000    0.001    8855551.719666
# 7          semi_naive_CSR_SDDMM_GPU  10000x10000   0.0005    4451327.800751
# 8          semi_naive_CSR_SDDMM_GPU  10000x10000   0.0001     959487.974644
# 9          semi_naive_CSR_SDDMM_GPU  10000x10000  0.00001     130048.006773
# 10  coo_opt_vectorization_SDDMM_GPU    1000x1000    0.005     212293.000000
# 11  coo_opt_vectorization_SDDMM_GPU    1000x1000    0.001     257243.000000
# 12  coo_opt_vectorization_SDDMM_GPU    1000x1000   0.0005     169842.000000
# 13  coo_opt_vectorization_SDDMM_GPU    1000x1000   0.0001      38761.000000
# 14  coo_opt_vectorization_SDDMM_GPU    1000x1000  0.00001      24030.000000
# 15  coo_opt_vectorization_SDDMM_GPU  10000x10000    0.005   98851026.000000
# 16  coo_opt_vectorization_SDDMM_GPU  10000x10000    0.001   31092337.000000
# 17  coo_opt_vectorization_SDDMM_GPU  10000x10000   0.0005   12903608.000000
# 18  coo_opt_vectorization_SDDMM_GPU  10000x10000   0.0001    4160860.000000
# 19  coo_opt_vectorization_SDDMM_GPU  10000x10000  0.00001    4275212.000000
# 20              naive_coo_SDDMM_GPU    1000x1000    0.005     637952.029705
# 21              naive_coo_SDDMM_GPU    1000x1000    0.001     808960.020542
# 22              naive_coo_SDDMM_GPU    1000x1000   0.0005     498688.012362
# 23              naive_coo_SDDMM_GPU    1000x1000   0.0001     114688.001573
# 24              naive_coo_SDDMM_GPU    1000x1000  0.00001      37888.001651
# 25              naive_coo_SDDMM_GPU  10000x10000    0.005  248151046.752930
# 26              naive_coo_SDDMM_GPU  10000x10000    0.001   76040191.650391
# 27              naive_coo_SDDMM_GPU  10000x10000   0.0005   38802433.013916
# 28              naive_coo_SDDMM_GPU  10000x10000   0.0001   15737855.911255
# 29              naive_coo_SDDMM_GPU  10000x10000  0.00001   16181247.711182
# 30                  naive_SDDMM_GPU    1000x1000    0.005     239647.999406
# 31                  naive_SDDMM_GPU    1000x1000    0.001     236543.998122
# 32                  naive_SDDMM_GPU    1000x1000   0.0005     238591.998816
# 33                  naive_SDDMM_GPU    1000x1000   0.0001     240639.999509
# 34                  naive_SDDMM_GPU    1000x1000  0.00001     238591.998816
# 35                  naive_SDDMM_GPU  10000x10000    0.005  155268096.923828
# 36                  naive_SDDMM_GPU  10000x10000    0.001  155657211.303711
# 37                  naive_SDDMM_GPU  10000x10000   0.0005  156361724.853516
# 38                  naive_SDDMM_GPU  10000x10000   0.0001  154949630.737305
# 39                  naive_SDDMM_GPU  10000x10000  0.00001  156824569.702148
# 40                           merged    1000x1000    0.005     121855.996549
# 41                           merged    1000x1000    0.001      41983.999312
# 42                           merged    1000x1000   0.0005      30719.999224
# 43                           merged    1000x1000   0.0001      20479.999483
# ['0.00001' '0.0001' '0.0005' '0.001' '0.005']
# ['coo_opt_vectorization_SDDMM_GPU' 'merged' 'naive_SDDMM_GPU'
#  'naive_coo_SDDMM_GPU' 'semi_naive_CSR_SDDMM_GPU']
# ['1000x1000' '10000x10000']
# ['0.001%' '0.01%' '0.05%' '0.1%' '0.5%']
#                        implementation       size sparsity            ns  \
# 0     coo_opt_vectorization_SDDMM_GPU  1000x1000   0.001%  23340.000000
# 1     coo_opt_vectorization_SDDMM_GPU  1000x1000   0.001%  23580.000000
# 2     coo_opt_vectorization_SDDMM_GPU  1000x1000   0.001%  23581.000000
# 3     coo_opt_vectorization_SDDMM_GPU  1000x1000   0.001%  23660.000000
# 4     coo_opt_vectorization_SDDMM_GPU  1000x1000   0.001%  23371.000000
# ...                               ...        ...      ...           ...
# 3245         semi_naive_CSR_SDDMM_GPU  1000x1000     0.5%  53247.999400
# 3246         semi_naive_CSR_SDDMM_GPU  1000x1000     0.5%  54271.999747
# 3247         semi_naive_CSR_SDDMM_GPU  1000x1000     0.5%  54271.999747
# 3248         semi_naive_CSR_SDDMM_GPU  1000x1000     0.5%  53247.999400
# 3249         semi_naive_CSR_SDDMM_GPU  1000x1000     0.5%      1.000000
#
#                          configuration
# 0     size: 1000x1000 sparsity: 0.001%
# 1     size: 1000x1000 sparsity: 0.001%
# 2     size: 1000x1000 sparsity: 0.001%
# 3     size: 1000x1000 sparsity: 0.001%
# 4     size: 1000x1000 sparsity: 0.001%
# ...                                ...
# 3245    size: 1000x1000 sparsity: 0.5%
# 3246    size: 1000x1000 sparsity: 0.5%
# 3247    size: 1000x1000 sparsity: 0.5%
# 3248    size: 1000x1000 sparsity: 0.5%
# 3249    size: 1000x1000 sparsity: 0.5%
#
# [3250 rows x 5 columns]

# %% [markdown]
# ### Scaling plots

# %%
def plotting_simple(data_to_plot, impl, iteration_metric, x_axis, x_axis_label):
    sns.set_theme(style="whitegrid")
    sns.set(rc={'figure.figsize':(30,8.27)})
    ax = sns.barplot(data= data_to_plot, x = x_axis, y = "ns", estimator='median', errorbar='ci')

    if log_scale:
        ax.set_yscale('log')

    if x_axis_label == "size":
        ax.set_title(impl + ", sparsity: " + str(iteration_metric))
    elif x_axis_label == "sparsity":
        ax.set_title(impl + ", size: " + str(iteration_metric))
    ax.set_ylabel("time in ns")
    ax.set_xlabel(x_axis_label)

    # save plot
    fig = ax.get_figure()
    # use a non standard seperator to read the asocited parts from the file name easier
    separator = "  "
    if x_axis_label == "size":
        fig.savefig("plots/correctness_test_jiela/scaling/impl_name=" + impl + separator + "sparsity=" + str(sparsity) + ".png")
    elif x_axis_label == "sparsity":
        fig.savefig("plots/correctness_test_jiela/scaling/impl_name=" + impl + separator + "size=" + size + ".png")
    fig.clf()  # reset seaborn to avoid stuff from accumulating



# 1: fix implementation, fix size, iterate over sparsity DAS HIER DU HORNOCHSE
for impl in impls:
    # This is only relevant if there is an implementation we don't want in our plot
    if impl in implementations_to_ignore:
         continue
    
    for size in sizes:

        # for sparsity in sparsities:  # there should be no need for .unique()

            d_to_plt = d_exp[d_exp['size'] == size]
            d_to_plt = d_to_plt[d_to_plt['implementation'] == impl]

            plotting_simple(d_to_plt, impl, size, "sparsity", "sparsity")
if consistency_check: print()

# 2: fix implementation, fix sparsity, iterate over size
it = 1
for impl in impls:
    # This is only relevant if there is an implementation we don't want in our plot
    if impl in implementations_to_ignore:
         continue
    
    for sparsity in sparsities:

            d_to_plt = d_exp[d_exp['implementation'] == impl]
            d_to_plt = d_to_plt[d_to_plt['sparsity'] == sparsity]

            plotting_simple(d_to_plt, impl, sparsity, "size", "size")
if consistency_check: print()

# %% [markdown]
# ### All in one plots

# %%
from matplotlib.container import ErrorbarContainer


def grouped_plotting(data_to_plot, group_iterator, fixed_metric):

    sns.set(style="whitegrid")
    sns.set(rc={'figure.figsize':(30,8.27)})

    if group_iterator == "size":
        hue = "size"
        hue_order = sizes
    elif group_iterator == "sparsity":
        hue = "sparsity"
        hue_order = sparsities
    elif group_iterator == "configuration":
        hue = "configuration"
        hue_order = configurations
    
    ax = sns.barplot(x="implementation", y="ns", hue=hue, hue_order=hue_order, data=data_to_plot, estimator='median', errorbar='ci')

    if log_scale:
        ax.set_yscale('log')
        
    # print("doing all in one plot")
    sns.set(rc={'figure.figsize':(60,8.27)})
    separator = "  "
    fig = ax.get_figure()
    ax.set_xlabel("implementation")
    ax.set_ylabel("time in ns")
    # plt.yscale('log')
    if group_iterator == "sparsity":
        ax.set_title("size: " + str(fixed_metric))
        fig.savefig("plots/correctness_test_jiela/all_impls/size=" + str(fixed_metric) + ".png")
    elif group_iterator == "size":
        ax.set_title("sparsity: " + str(fixed_metric))
        fig.savefig("plots/correctness_test_jiela/all_impls/sparsity=" + str(fixed_metric) + ".png")
    elif group_iterator == "configuration":
        ax.set_title("Special Configurations")
        fig.savefig("plots/correctness_test_jiela/all_impls/special_config.png")
    fig.clf()  # reset seaborn to avoid stuff from accumulating
    

# 1. fix sparsity, group iterator = size, x-axis-ticks iterator = implementation
for sparsity in sparsities:

    d_to_plt = d_exp[d_exp['sparsity'] == sparsity]

    # This is only relevant if there is an implementation we don't want in our plot
    for impl in implementations_to_ignore:
        d_to_plt = d_to_plt[d_to_plt['implementation' != impl]]

    grouped_plotting(d_to_plt, "size", sparsity)


if consistency_check: print()

# 2. fix size, group iterator = sparsity, x-axis-ticks iterator = implementation
for size in sizes:
    
    d_to_plt = d_exp[d_exp['size'] == size]

    # This is only relevant if there is an implementation we don't want in our plot
    for impl in implementations_to_ignore:
        d_to_plt = d_to_plt[d_to_plt['implementation' != impl]]

    grouped_plotting(d_to_plt,"sparsity", size)

if consistency_check: print()

# 3. here we just have a grouped plot for the special config
d_to_plt = d_exp[d_exp['configuration'] != "No"]

# This is only relevant if there is an implementation we don't want in our plot
for impl in implementations_to_ignore:
    d_to_plt = d_to_plt[d_to_plt['implementation' != impl]]

grouped_plotting(d_to_plt, "configuration", "dummy")
