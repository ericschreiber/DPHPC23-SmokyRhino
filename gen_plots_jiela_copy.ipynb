# %%
import pandas as pd
import os
import seaborn as sns

# kill old plots
for f in os.listdir('plots/scaling'):
    os.remove(os.path.join('plots/scaling', f))
for f in os.listdir('plots/all_impls'):
    os.remove(os.path.join('plots/all_impls', f))

# %% [markdown]
# ### Global params

# %%
num_warmups = 5  # with the full data this should probably be something like 20
consistency_check = False

# %% [markdown]
# ### Load data

# %%
base_path = "/scratch/eschreib/results_ABsquare/"

# collect all files that contain run data
file_paths = []
impl_name = os.listdir(base_path)
for impl in impl_name:
    sizes = os.listdir(base_path + impl)
    # there is exactly one csv file per size_dir
    for size_dir in sizes:
        files = os.listdir(base_path + impl + "/" + size_dir)
        file_path = base_path + impl + "/" + size_dir + "/" + files[0]  # only one csv file per dir
        file_paths.append(file_path)
data = []
for file in file_paths:
    with open(file, 'r') as fin:
        size = file.split("/")[-2]
        lines = fin.readlines()
        lines.pop(0)  # remove header line
        lines = list(map(lambda x: x.replace(",\n", ""), lines))  # remove trailing newline since they would create an extra column at the end
        lines = list(map(lambda x: x.split(","), lines))  # split into columns
        lines = list(map(lambda x: [x[0]] + ["0." + (x[3].split("/")[-1].split(".")[0].split("_")[-1][1:])] + x[1:], lines))
        lines = list(map(lambda x: [x[0]] + [size] + x[1:], lines))  # add size info
        data += lines
# wrap all the data into one big dataframe
data = pd.DataFrame(data)

data
# Out:
#                                  0            1        2   \
# 0          semi_naive_CSR_SDDMM_GPU    1000x1000    0.005
# 1          semi_naive_CSR_SDDMM_GPU    1000x1000    0.001
# 2          semi_naive_CSR_SDDMM_GPU    1000x1000   0.0005
# 3          semi_naive_CSR_SDDMM_GPU    1000x1000   0.0001
# 4          semi_naive_CSR_SDDMM_GPU    1000x1000  0.00001
# 5          semi_naive_CSR_SDDMM_GPU  10000x10000    0.005
# 6          semi_naive_CSR_SDDMM_GPU  10000x10000    0.001
# 7          semi_naive_CSR_SDDMM_GPU  10000x10000   0.0005
# 8          semi_naive_CSR_SDDMM_GPU  10000x10000   0.0001
# 9          semi_naive_CSR_SDDMM_GPU  10000x10000  0.00001
# 10  coo_opt_vectorization_SDDMM_GPU    1000x1000    0.005
# 11  coo_opt_vectorization_SDDMM_GPU    1000x1000    0.001
# 12  coo_opt_vectorization_SDDMM_GPU    1000x1000   0.0005
# 13  coo_opt_vectorization_SDDMM_GPU    1000x1000   0.0001
# 14  coo_opt_vectorization_SDDMM_GPU    1000x1000  0.00001
# ...

# %% [markdown]
# ### Preprocess data

# %%
# remove warmup measurements
metadata = data.iloc[:, :3]
measurements = data.iloc[:, 3:]
measurements = measurements.iloc[:, num_warmups:]
data = pd.concat([metadata, measurements], axis=1)

# remove all the broken runs (= the impls that start with "**")
data = data[~data[0].str.startswith("**")]

# prettify df
data = data.drop(data.columns[[3, 4, 5]], axis=1)  # rm the paths to the matrices
data = data.sort_values(by=[0])  # sort by implementation name
data.columns = range(data.shape[1])  # reset the column names to consecutive numbers
data.head()

impls = data[0].unique()
sizes = data[1].unique()
sparsities = data[2].unique()
sparsities.sort()  # if I don't seaborn messes up the order of the x axis in some plots

print(impls)
print(sizes)
print(sparsities)

# data
# print(data)

# We now expand such that we can use seaborn
# specifically this means we only have one measurement per row
#d_exp stands for data expanded. Meaning each row only contains a single measurement
 
d_exp = pd.DataFrame(columns=['implementation', 'size', 'sparsity', 'ns'])

for row_idx in range(len(data)):

    row = data.iloc[row_idx]
    row_len = len(row)

    cur_imp = row[0]
    cur_size = row[1]
    cur_spars = row[2]

    for measurement in row[3:]:

        new_row = {'implementation': cur_imp, 'size': cur_size, 'sparsity': cur_spars, 'ns': float(measurement)}
        d_exp.loc[len(d_exp)] = new_row


d_exp
# Out:
# ['coo_opt_vectorization_SDDMM_GPU' 'naive_SDDMM_GPU' 'naive_coo_SDDMM_GPU'
#  'semi_naive_CSR_SDDMM_GPU']
# ['10000x10000' '1000x1000']
# ['0.00001' '0.0001' '0.0005' '0.001' '0.005']
#                        implementation         size sparsity            ns
# 0     coo_opt_vectorization_SDDMM_GPU  10000x10000  0.00001  4.276082e+06
# 1     coo_opt_vectorization_SDDMM_GPU  10000x10000  0.00001  4.273772e+06
# 2     coo_opt_vectorization_SDDMM_GPU  10000x10000  0.00001  4.273472e+06
# 3     coo_opt_vectorization_SDDMM_GPU  10000x10000  0.00001  4.276931e+06
# 4     coo_opt_vectorization_SDDMM_GPU  10000x10000  0.00001  4.277591e+06
# ...                               ...          ...      ...           ...
# 1795         semi_naive_CSR_SDDMM_GPU    1000x1000    0.005  5.427200e+04
# 1796         semi_naive_CSR_SDDMM_GPU    1000x1000    0.005  5.324800e+04
# 1797         semi_naive_CSR_SDDMM_GPU    1000x1000    0.005  5.427200e+04
# ...

# %% [markdown]
# ### Utils

# %%
# def filter_data(input, impl, size, sparsity):
#     filtered = input.loc[(input[0] == impl) & (input[1] == size) & (input[2] == sparsity)]
#     measurements = filtered.drop(filtered.columns[[0, 1, 2]], axis=1)
#     measurements.columns = range(measurements.shape[1])  # reset cols to consecutive numbers
#     return measurements

# def get_stats(measurements):
#     measurements = measurements.astype(float)
#     mean = measurements.mean(axis=1).values[0]
#     std_dev = measurements.std(axis=1).values[0]  # TODO: not std but confidence interval
#     return mean, std_dev

# %% [markdown]
# ### Scaling plots

# %%
def plotting_simple(impl, sparsity, size, x_axis, x_axis_label):
    sns.set_theme(style="whitegrid")
    sns.set(rc={'figure.figsize':(30,8.27)})
    ax = sns.barplot(data= d_exp, x = x_axis, y = "ns", estimator='median', errorbar='ci')

    if x_axis_label == "size":
        ax.set_title(impl + ", sparsity: " + str(sparsity))
    elif x_axis_label == "sparsity":
        ax.set_title(impl + ", size: " + size)
    ax.set_ylabel("time in ms")
    ax.set_xlabel(x_axis_label)

    # save plot
    fig = ax.get_figure()
    # use a non standard seperator to read the asocited parts from the file name easier
    separator = "  "
    if x_axis_label == "size":
        fig.savefig("plots/scaling/impl_name=" + impl + separator + "sparsity=" + str(sparsity) + ".png")
    elif x_axis_label == "sparsity":
        fig.savefig("plots/scaling/impl_name=" + impl + separator + "size=" + size + ".png")
    fig.clf()  # reset seaborn to avoid stuff from accumulating


def scaling_plot(impl, sparsity, size, means, std_devs, x_axis, x_axis_label):
    # plot means and the std_devs as bars with handles
    sns.set_theme(style="whitegrid")
    sns.set(rc={'figure.figsize':(30,8.27)})
    ax = sns.barplot(x=x_axis, y=means)
    if x_axis_label == "size":
        ax.set_title(impl + ", sparsity: " + str(sparsity))
    elif x_axis_label == "sparsity":
        ax.set_title(impl + ", size: " + size)
    ax.set_ylabel("time in ms")
    ax.set_xlabel(x_axis_label)
    # add error bars
    for i in range(len(means)):
        ax.errorbar(i, means[i], yerr=std_devs[i], ecolor='black', capsize=3)
    # save plot
    fig = ax.get_figure()
    # use a non standard seperator to read the asocited parts from the file name easier
    separator = "  "
    if x_axis_label == "size":
        fig.savefig("plots/scaling/impl_name=" + impl + separator + "sparsity=" + str(sparsity) + ".png")
    elif x_axis_label == "sparsity":
        fig.savefig("plots/scaling/impl_name=" + impl + separator + "size=" + size + ".png")
    fig.clf()  # reset seaborn to avoid stuff from accumulating

# 1: fix implementation, fix size, iterate over sparsity DAS HIER DU HORNOCHSE
for impl in impls:
    for size in sizes:
        means = []
        std_devs = []
        for sparsity in sparsities:  # there should be no need for .unique()


   
            if consistency_check: print(impl, size, means, std_devs)
            plotting_simple(impl, sparsity, size, "sparsity", "sparsity")
if consistency_check: print()

# 2: fix implementation, fix sparsity, iterate over size
# for impl in impls:
#     for sparsity in sparsities:
#         means = []
#         std_devs = []
#         for size in sizes:
#             measurements = filter_data(data, impl, size, sparsity)
#             if measurements.shape[0] == 0:
#                 print("WARNING: for the following run config no data has been collected \n implementation_name: " + impl + ", size: " + size + ", sparsity: " + str(sparsity))
#                 means.append(0)
#                 std_devs.append(0)
#                 continue
#             mean, std_dev = get_stats(measurements)
#             means.append(mean)
#             std_devs.append(std_dev)
#         if consistency_check: print(impl, sparsity, means, std_devs)
#         scaling_plot(impl, sparsity, size, means, std_devs, sizes, "size")
# if consistency_check: print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 58
#      53         for sparsity in sparsities:  # there should be no need for .unique()
#      57             if consistency_check: print(impl, size, means, std_devs)
# ---> 58             plotting_simple(impl, sparsity, size, sparsities, "sparsity")
#      59 if consistency_check: print()
#      61 # 2: fix implementation, fix sparsity, iterate over size
#      62 # for impl in impls:
#      63 #     for sparsity in sparsities:
#    (...)
#      77 #         scaling_plot(impl, sparsity, size, means, std_devs, sizes, "size")
#      78 # if consistency_check: print()
#
# Cell In[25], line 4, in plotting_simple(impl, sparsity, size, x_axis, x_axis_label)
#       2 sns.set_theme(style="whitegrid")
#       3 sns.set(rc={'figure.figsize':(30,8.27)})
# ...

# %% [markdown]
# ### All in one plots

# %%
from matplotlib.container import ErrorbarContainer

def all_impls_plot(data, impl, sparsity, size, group_iterator, num_impls, len_group_iterator):
    sns.set(style="whitegrid")
    sns.set(rc={'figure.figsize':(30,8.27)})
    if group_iterator == "size":
        hue = "Size"
    elif group_iterator == "sparsity":
        hue = "Sparsity"
    ax = sns.barplot(x='Implementation', y="Value", hue=hue, data=data)
    sns.set(rc={'figure.figsize':(60,8.27)})
    separator = "  "
    fig = ax.get_figure()
    ax.set_xlabel("implementation")
    ax.set_ylabel("time in ms")
    # manually add error bars
    for j in range(num_impls):
        container = ax.containers[j]
        if type(container) == ErrorbarContainer: continue
        for i, bar in enumerate(container.patches):
            idx = j * len_group_iterator + i
            ax.errorbar(x=bar.get_x() + bar.get_width() / 2, y=bar.get_height(), yerr=data['std_dev'][idx], color='black', capsize=3)
    if group_iterator == "size":
        ax.set_title("sparsity: " + str(sparsity))
        fig.savefig("plots/all_impls/impl_name=" + impl + separator + "sparsity=" + str(sparsity) + ".png")
    elif group_iterator == "sparsity":
        ax.set_title("size: " + size)
        fig.savefig("plots/all_impls/impl_name=" + impl + separator + "size=" + size + ".png")
    fig.clf()  # reset seaborn to avoid stuff from accumulating

# 1. fix sparsity, group iterator = size, x-axis-ticks iterator = implementation
for sparsity in sparsities:
    grouped_data = {'Size': [], 'Implementation': [], 'Value': [], 'std_dev': []}
    for impl in impls:
        for size in sizes:
            measurements = filter_data(data, impl, size, sparsity)
            if measurements.shape[0] == 0:
                print("WARNING: for the following run config no data has been collected \n implementation_name: " + impl + ", size: " + size + ", sparsity: " + str(sparsity))
                continue
            mean, std_dev = get_stats(measurements)
            grouped_data['Size'].append(size)
            grouped_data['Implementation'].append(impl)
            grouped_data['Value'].append(mean)
            grouped_data['std_dev'].append(std_dev)
    grouped_data = pd.DataFrame(grouped_data)
    if consistency_check: print("sparsity: " + str(sparsity) + "\n" + str(grouped_data))
    all_impls_plot(grouped_data, impl, sparsity, None, "size", len(impls), len(sizes))
if consistency_check: print()

# 2. fix size, group iterator = sparsity, x-axis-ticks iterator = implementation
for size in sizes:
    grouped_data = {'Sparsity': [], 'Implementation': [], 'Value': [], 'std_dev': []}
    for impl in impls:
        for sparsity in sparsities:
            measurements = filter_data(data, impl, size, sparsity)
            if measurements.shape[0] == 0:
                print("WARNING: for the following run config no data has been collected \n implementation_name: " + impl + ", size: " + size + ", sparsity: " + str(sparsity))
                continue
            mean, std_dev = get_stats(measurements)
            grouped_data['Sparsity'].append(sparsity)
            grouped_data['Implementation'].append(impl)
            grouped_data['Value'].append(mean)
            grouped_data['std_dev'].append(std_dev)
    grouped_data = pd.DataFrame(grouped_data)
    if consistency_check: print("size: " + size + "\n" + str(grouped_data))
    print("sparsity: " + str(sparsity) + "\n" + str(grouped_data))
    all_impls_plot(grouped_data, impl, None, size, "sparsity", len(impls), len(sparsities))
if consistency_check: print()
# Out:
# sparsity: 0.005
#    Sparsity                   Implementation         Value       std_dev
# 0   0.00001  coo_opt_vectorization_SDDMM_GPU  4.277895e+06  3.064816e+03
# 1    0.0001  coo_opt_vectorization_SDDMM_GPU  4.156486e+06  2.813630e+03
# 2    0.0005  coo_opt_vectorization_SDDMM_GPU  1.290639e+07  5.216437e+03
# 3     0.001  coo_opt_vectorization_SDDMM_GPU  2.988029e+07  1.089285e+06
# 4     0.005  coo_opt_vectorization_SDDMM_GPU  9.909736e+07  1.668907e+05
# 5   0.00001                  naive_SDDMM_GPU  1.561417e+08  6.575748e+05
# 6    0.0001                  naive_SDDMM_GPU  1.561098e+08  7.200432e+05
# 7    0.0005                  naive_SDDMM_GPU  1.562876e+08  6.853347e+05
# 8     0.001                  naive_SDDMM_GPU  1.559691e+08  7.770465e+05
# 9     0.005                  naive_SDDMM_GPU  1.550636e+08  4.313251e+05
# 10  0.00001              naive_coo_SDDMM_GPU  1.618104e+07  1.128631e+04
# 11   0.0001              naive_coo_SDDMM_GPU  1.573472e+07  1.681104e+04
# ...
